# %%
class Website:
    
    #--------------------------------------------------------------------------
    # CONSTRUCTOR
    #--------------------------------------------------------------------------

    def __init__(self,                     
                 ID,                         # ID of the website.
                 url,                        # URL of the website.
                 content_type,               # Contet Type of the website.
                 language,                   # 
                 urls = [], 
                 social_networks_urls=[], 
                 text="", 
                 names= [], 
                 locations = [],
                 iframes = [], 
                 organizations=[], 
                 dates = [], 
                 phonenumbers = [], 
                 images_urls = [],  
                 payment_accounts= [], 
                 emails=[]):
        
        self.__ID = ID # (SHA256, "http://titulopagina.com")
        self.__url = url
        self.__content_type = content_type
        self.__language = language
        self.__names =names
        self.__locations=locations
        self.__urls=urls
        self.__phonenumbers=phonenumbers
        self.__iframes = iframes
        self.__images_urls=images_urls
        self.__dates=dates
        self.__payment_accounts=payment_accounts
        self.__emails=emails
        self.__organizations=organizations
        self.__text=text
        self.__social_networks=social_networks
        
    #--------------------------------------------------------------------------
    # METODOS
    #--------------------------------------------------------------------------
    
    def info(self):
        print("ID: " + self.__ID)
        print("URL: " + self.__url)
        print("Language: " + self.__language)
        print("Names found: " + self.__names)
        print("Locations: " + self.__locations)
        print("URLS: " + self.__urls)
        print("Phone numbers: " + self.__phonenumbers)
        print("IFRames: " + self.__iframes)
        print("Images URLS: " + self.__images_urls)
        print("Dates: " + self.__dates)
        print("Payment Accounts: " + self.__payment_accounts)
        print("Emails: " + self.__emails)
        print("Organizations: " + self.__organizations)
        print("Social Networks: " + self.__social_networks)
        print("Text: " + self.__text)
        
    def __str__(self):
        return "Node ID" + self.__ID
    
    def toTextPlain(self):
        return ""
    
    # This method recomputes all the attributes of the website, except the ID and URL.
    def reCompute(self):
        
        # Generate a new witness to re-explore the page.
        witness = TheWitness(
            self.__url, 
            self.__url,
            self.__ID, 
            0
        )
        result = witness.scrap()
        
        self.setContentType(result[3])
        self.setLanguage(result[4])
        #self.
        
        
        return ""
        
    #--------------------------------------------------------------------------
    # METODOS SET
    #--------------------------------------------------------------------------
    
    def setContentType(self, new_content_type):
        self.__content_type = new_content_type
    
    def setLanguage(self, newLanguage):
        self.__language = newLanguage
        
    def setNames(self, newNames):
        self.__names = newNames   
        
    def setLocations(self, newLocations):
        self.__locations = newLocations
        
    def setUrls(self, newUrls):
        self.__urls = newUrls
        
    def setNumbers(self, newNumbers):
        self.__numbers = newNumbers
        
    def setCoordinates(self, newCoordinates):
        self.__coordinates = newCoordinates
        
    def setImages(self, newImages):
        self.__images = newImages
        
    def setDates(self, newDates):
        self.__dates = newDates
        
    def setPaymentAccounts(self, newPaymentAccounts):
        self.__payment_accounts = newPaymentAccounts
        
    def setEmails(self, newEmails):
        self.__emails = newEmails
        
    def setOrganizations(self, newOrganizations):
        self.__organizations = newOrganizations
        
    def setText(self, newText):
        self.__text = newText
        
    def setSocialNetworks(self, newSocialNetworks):
        self.__social_networks = newSocialNetworks
        
    #--------------------------------------------------------------------------
    # METODOS GET
    #--------------------------------------------------------------------------
    
    def getID(self):
        return self.__ID
    
    def getUrl(self):
        return self.__url
    
    def getContentType(self): 
        return self.__content_type
    
    def getLanguage(self):
        return self.__language
    
    def getNames(self):
        return self.__names
    
    def getLocations(self):
        return self.__locations
    
    def getUrls(self):
        return self.__urls
    
    def getNumbers(self):
        return self.__numbers
    
    def getIframes(self):
        return self.__iframes
    
    def getImages(self):
        return self.__images
    
    def getDates(self):
        return self.__dates
    
    def getPaymentAccounts(self):
        return self.__payment_accounts
    
    def getEmails(self):
        return self.__emails
    
    def getOrganizations(self):
        return self.__organizations
    
    def getText(self):
        return self.__text
    
    def getSocialNetworks(self):
        return self.__social_networks

# %%
def printFormat(self, list_):
    for i in range(len(list_)): 
        print("--------")
        print(lista_par[i])
        if type(result[i]) == list:
            for element in result[i]:
                print(element)
        else: 
            print(result[i])
        print("\n")
