# %%
class Website:
    
    #--------------------------------------------------------------------------
    # CONSTRUCTOR
    #--------------------------------------------------------------------------               

    def __init__(self,                     
                 ID,                         # ID of the website.
                 url,                        # URL of the website.
                 content_type,               # Contet Type of the website.
                 language,                   # Language of the website.
                 urls = [],                  # URLS found on the website.
                 social_networks_urls=[],    # Social networks urls.
                 text="",                    # Text of the website.
                 names= [],                  # Names that appeared on the website.
                 locations = [],             # Locations mentioned on website.
                 iframes = [],               # Iframes code (maps or videos) that appear on the website.
                 organizations=[],           # Organization names.
                 dates = [],                 # Dates on the website.
                 phonenumbers = [],          # Phonenumbers on the website.
                 images_urls = [],           # Images urls.
                 payment_accounts= [],       # Payment Accounts (banks, crytpo).
                 emails=[]):                 # Emails on the website.
        
        self.__ID = ID # (SHA256, "http://titulopagina.com")
        self.__url = url
        self.__content_type = content_type
        self.__language = language
        self.__names =names
        self.__locations=locations
        self.__urls=urls
        self.__phonenumbers=phonenumbers
        self.__iframes = iframes
        self.__images_urls=images_urls
        self.__dates=dates
        self.__payment_accounts=payment_accounts
        self.__emails=emails
        self.__organizations=organizations
        self.__text=text
        self.__social_networks=social_networks_urls
        
    #--------------------------------------------------------------------------
    # METHODS
    #--------------------------------------------------------------------------
    
    def printFormat(self, list_):
        for i in range(len(list_)): 
            print("--------")
            print(lista_par[i])
        if type(result[i]) == list:
            for element in result[i]:
                print(element)
        else: 
            print(result[i])
            print("\n")
    
    def info(self):
        print("--------")
        print("ID: ")
        print(self.__ID)
        print("--------")
        print("URL: ")
        print(self.__url)
        print("--------")
        print("Language: ")
        print(self.__language)
        print("--------")
        print("Names found: ")
        print(printFormat(self.__names))
        print("--------")
        print("Locations: ")
        print(printFormat(self.__locations))
        print("--------")
        print("URLS: ")
        print(printFormat(self.__urls))
        print("--------")
        print("Phone numbers: ")
        print(printFormat(self.__phonenumbers))
        print("--------")
        print("IFRames: ")
        print(printFormat(self.__iframes))
        print("--------")
        print("Images URLS: ")
        print(printFormat(self.__images_urls))
        print("--------")
        print("Dates: ")
        print(printFormat(self.__dates))
        print("--------")
        print("Payment Accounts: ")
        print(printFormat(self.__payment_accounts))
        print("--------")
        print("Emails: ")
        print(printFormat(self.__emails))
        print("--------")
        print("Organizations: ") 
        print(printFormat(self.__organizations))
        print("--------")
        print("Social Networks: ")
        print(printFormat(self.__social_networks))
        print("--------")
        print("Text: ")
        print(self.__text)
        
    def __str__(self):
        return "Node ID " + self.__ID
    
    def toTextPlain(self, ruta):
        file = open("./datasets/"+self.ID+".txt")
        file.write()
        file.write("--------")
        file.write("ID: ")
        file.write(self.__ID)
        file.write("--------")
        file.write("URL: ")
        file.write(self.__url)
        file.write("--------")
        file.write("Language: ")
        file.write(self.__language)
        file.write("--------")
        file.write("Names found: ")
        file.write(printFormat(self.__names))
        file.write("--------")
        file.write("Locations: ")
        file.write(printFormat(self.__locations))
        file.write("--------")
        file.write("URLS: ")
        file.write(printFormat(self.__urls))
        file.write("--------")
        file.write("Phone numbers: ")
        file.write(printFormat(self.__phonenumbers))
        file.write("--------")
        file.write("IFRames: ")
        file.write(printFormat(self.__iframes))
        file.write("--------")
        file.write("Images URLS: ")
        file.write(printFormat(self.__images_urls))
        file.write("--------")
        file.write("Dates: ")
        file.write(printFormat(self.__dates))
        file.write("--------")
        file.write("Payment Accounts: ")
        file.write(printFormat(self.__payment_accounts))
        file.write("--------")
        file.write("Emails: ")
        file.write(printFormat(self.__emails))
        file.write("--------")
        file.write("Organizations: ") 
        file.write(printFormat(self.__organizations))
        file.write("--------")
        file.write("Social Networks: ")
        file.write(printFormat(self.__social_networks))
        file.write("--------")
        file.write("Text: ")
        file.write(self.__text)
        file.close()
    
    
    # This method recomputes all the attributes of the website, except the ID and URL.
    def reCompute(self):
        # Generate a new witness to re-explore the page.
        witness = TheWitness(
                self.__url, 
                self.__url,
                self.__ID, 
                0 )
        try:         
            result = witness.scrap()

            self.setContentType(result[2])
            self.setLanguage(result[3])
            self.setUrls(result[4])
            self.setSocialNetworks(result[5])
            self.setText(result[6])
            self.setNames(result[7])
            self.setLocations(result[8])
            self.setIframes(result[9])
            self.setOrganizations(result[10])
            self.setDates(result[11])
            self.setNumbers(result[12])
            self.setImages(result[13])
            self.setPaymentAccounts(result[14])
            self.setEmails(result[15])
            del witness
            return True
        
        except:
            del witness
            return False
        
    #--------------------------------------------------------------------------
    # SET METHODS
    #--------------------------------------------------------------------------
    
    def setContentType(self, new_content_type):
        self.__content_type = new_content_type
    
    def setLanguage(self, newLanguage):
        self.__language = newLanguage
        
    def setNames(self, newNames):
        self.__names = newNames   
        
    def setLocations(self, newLocations):
        self.__locations = newLocations
        
    def setUrls(self, newUrls):
        self.__urls = newUrls
        
    def setNumbers(self, newNumbers):
        self.__numbers = newNumbers
        
    def setIframes(self, newIframes):
        self.__iframes = newIframes
        
    def setImages(self, newImages):
        self.__images = newImages
        
    def setDates(self, newDates):
        self.__dates = newDates
        
    def setPaymentAccounts(self, newPaymentAccounts):
        self.__payment_accounts = newPaymentAccounts
        
    def setEmails(self, newEmails):
        self.__emails = newEmails
        
    def setOrganizations(self, newOrganizations):
        self.__organizations = newOrganizations
        
    def setText(self, newText):
        self.__text = newText
        
    def setSocialNetworks(self, newSocialNetworks):
        self.__social_networks = newSocialNetworks
        
    #--------------------------------------------------------------------------
    # GET METHODS
    #--------------------------------------------------------------------------
    
    def getID(self):
        return self.__ID
    
    def getUrl(self):
        return self.__url
    
    def getContentType(self): 
        return self.__content_type
    
    def getLanguage(self):
        return self.__language
    
    def getNames(self):
        return self.__names
    
    def getLocations(self):
        return self.__locations
    
    def getUrls(self):
        return self.__urls
    
    def getNumbers(self):
        return self.__numbers
    
    def getIframes(self):
        return self.__iframes
    
    def getImages(self):
        return self.__images
    
    def getDates(self):
        return self.__dates
    
    def getPaymentAccounts(self):
        return self.__payment_accounts
    
    def getEmails(self):
        return self.__emails
    
    def getOrganizations(self):
        return self.__organizations
    
    def getText(self):
        return self.__text
    
    def getSocialNetworks(self):
        return self.__social_networks
