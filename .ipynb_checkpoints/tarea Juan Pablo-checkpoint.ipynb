rel="alternate"/>
# <link href="https://www.streamate.com/?langchoice=no" hreflang="no" rel="alternate"/>
# <link href="https://www.streamate.com/?langchoice=en" rel="canonical"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon-precomposed"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <script data-user-is="nonuser" id="js-naiad">
#   // Addresses an issue resulting from "Complitly" Chrome plugin/malware.
#   // stackoverflow.com/q/11501391
#   window.suggestmeyes_loaded = true;
# </script>
# <!-- Global site tag (gtag.js) - Google Ads: AW-715250222 -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-715250222"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'AW-715250222');
# </script>
# <!-- TP-GA code -->
# <script>
#
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#         ga('create', 'UA-8197088-49', 'auto', 'masterTracker');
#         ga('masterTracker.set', 'page', '/');
#         ga('masterTracker.send', 'pageview', {'dimension1': 'Guest','dimension3': '0','dimension4': ''});
#
#
#
#         </script>
# <script type="text/javascript">
#     function searchChangeSel( s ) {
#       s.form.pagenum.value = 1;
#       s.form.submit()
#     }
#   </script>
# </head>
# <body id="index">
# <div class="fallback-header container-bg-width" id="header-container">
# <div class="header clearfix ie6-login-fix">
# <h1 class="left">
# <a href="https://streamate.com/" title="Streamate Live Cams, Free Sex Cams, Sex 24/7">Streamate Live Cams, Free Sex Cams, Sex 24/7</a>
# </h1>
# <div class="login">
# <p id="join-button">
# <a href="https://streamate.com/signup/?" title="Join Streamate for free"><span>Join Free</span></a>
# </p>
# <div>
# <form accept-charset="utf-8" action="https://www.streamate.com/login.php" method="post">
# <input name="trylogin" type="hidden" value="1"/>
# <input name="g" type="hidden" value="Lw=="/>
# <input name="pagenum" type="hidden" value="1"/>
# <ul>
# <li>
# <label for="username">Email</label>
# <input class="text" id="username" name="sausr" type="text" value=""/>
# <label for="password">Password</label>
# <input class="text" id="password" name="sapwd" type="password" value=""/>
# </li>
# <li class="stacked-login">
# <label for="recognize">Remember Me</label>
# <input class="checkbox" id="recognize" name="recognize" type="checkbox" value="1"/><br/>
# <a href="https://www.streamate.com/forgot-password/" title="Click here if you forgot your password">Forgot your password?</a>
# </li>
# <li>
# <input class="header-submit" type="submit" value="Login"/>
# </li>
# </ul>
# </form>
# </div>
# </div>
# <div id="header-tools">
# <p id="choose-language">
# <a href="#languageSelectFooter" id="choose-language-toggle" title="">Choose your language »</a>
# <span id="choose-language-dropdown"><a href="https://streamate.com/?langchoice=de">Deutsch</a> | <a href="https://streamate.com/?langchoice=es">Español</a> | <a href="https://streamate.com/?langchoice=fr">Français</a> | <a href="https://streamate.com/?langchoice=it">Italiano</a> | <a href="https://streamate.com/?langchoice=nl">Nederlands</a> | <a href="https://streamate.com/?langchoice=no">Norsk</a> | <a href="https://streamate.com/?langchoice=pt">Português</a> | <a href="https://streamate.com/?langchoice=sv">Svenska</a></span>
# </p>
# </div>
# </div>
# </div>
# <div class="container-bg-width" id="nav-row-container">
# <div class="clearfix" id="nav-row">
# <div class="header">
# <ul class="nav-primary">
# <li class="first active"><a href="https://streamate.com/" title="Streamate Live Cams, Free Sex Cams, Sex 24/7">Home</a></li>
# <li class=""><a href="https://streamate.com/advanced-search.html" title="Search for models">Search</a></li>
# <li class=""><a href="https://streamate.com/new.php" title="View the latest models">New Models</a></li>
# <li class=""><a href="https://streamate.com/customer-service/" title="Contact customer support">Support</a></li>
# <li class=""><a href="https://www.streamate.com/login.php" title="Login to the member's area">Member Login</a></li>
# <li class="">
# <a href="https://streamate.com/shows/calendar/" title="Show Calendar">
#     Show Calendar
#   </a>
# </li>
# </ul>
# <form action="https://www.streamate.com/search.php" class="search-form" method="get">
# <input class="text q" id="search-anything" name="q" onblur="if(this.value=='')this.value='Search Anything'" onfocus="if(this.value=='Search Anything')this.value=''" type="text" value="Search Anything"/>
# <input id="search-submit" name="submit" type="submit" value="Search"/>
# </form>
# </div>
# </div>
# </div>
# <div class="public-note clearfix">
# <div class="clearfix">
# <h2 style="font-size:1.25em; line-height: 30px;">Soon we will no longer be supporting your device or browser. Please update to enjoy your chat experience.</h2>
# </div>
# </div>
# <div class="container-bg-width" id="wrapper-container">
# <div class="clearfix" id="wrapper">
# <div class="homepage" id="content">
# <div class="search-header">
# <h1>Live Sex Chat - Amateur Cams and Pornstars</h1>
# <form action="/index.php" method="get" name="lastsearch">
# <input name="pagenum" type="hidden" value="1"/>
# <div class="sort">
# <span>Sort by:</span>
# <select class="first" id="sort_language_sel" name="sort_language" onchange="searchChangeSel(this)">
# <option selected="selected" value="none">Languages</option><option value="en">English</option><option value="fr">French</option><option value="es">Spanish</option><option value="it">Italian</option><option value="de">German</option><option value="sv">Swedish</option><option value="pt">Portuguese</option><option value="nl">Dutch</option><option value="no">Norwegian</option>
# </select>
# <select class="" id="sort_region_sel" name="sort_region" onchange="searchChangeSel(this)">
# <option selected="selected" value="none">Regions</option><option value="na_uk_au">North America/UK/Australia</option><option value="west_eu">Western Europe</option><option value="cent_east_eu">Central/Eastern Europe</option><option value="cent_south_am">Central/South America</option><option value="asia">Asia</option><option value="africa">Africa</option>
# </select>
# <select class="last wide" id="sort_feature_sel" name="sort_feature" onchange="searchChangeSel(this)">
# <option selected="selected" value="none">Features</option><option value="hd">HD (best quality)</option><option value="audio">Audio</option><option value="phone">Phone</option><option value="party">Party Chat</option><option value="gold">Gold Show</option>
# </select>
# <noscript><button class="right" type="submit">Submit</button></noscript>
# </div>
# </form></div>
# </div></div></div></body></html>
# <div class="clearfix" id="cam-container">
# <div class="cam-result first" id="sr-89562097">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/itsdanilynn/" title="View itsdanilynn's bio">itsdanilynn</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/itsdanilynn/" title="View itsdanilynn's cam"><img alt="itsdanilynn" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/7/2/9729810.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/itsdanilynn/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="28 years old / Female / United States Of America">
# <p>28</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# </div>
# <div class="cam-result" id="sr-88456044">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/Amandababyxx/" title="View Amandababyxx's bio">Amandababyxx</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/Amandababyxx/" title="View Amandababyxx's cam"><img alt="Amandababyxx" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/8/6/9868256.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/Amandababyxx/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="22 years old / Female / United States Of America">
# <p>22</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# </div>
# <div class="cam-result" id="sr-31993987">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/KamiliaMae/" title="View KamiliaMae's bio">KamiliaMae</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/KamiliaMae/" title="View KamiliaMae's cam"><img alt="KamiliaMae" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/8/5/9852567.jpg" width="140"/></a>
# <p class="status online"><a href="https://streamate.com/cam/KamiliaMae/">Live Now</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="31 years old / Female / United States Of America">
# <p>31</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">Blonde slut with a tight pussy and fat ass here to please.</p>
# </div>
# <div class="cam-result" id="sr-44226314">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam
">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="42 years old / Female / Romania">
# <p>42</p>
# <p class="gender f">f</p>
# <p>RO</p>
# </div>
# <p class="headline">I am new here guys, come in and lets have some fun together ;)</p>
# </div>
# <div class="cam-result" id="sr-45101192">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/QueenKarma18/" title="View QueenKarma18's bio">QueenKarma…</a></h2>
# <ul class="cam-features">
# <li class="phone" title="Confidential Phone Service">Confidential Phone Service</li>
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/QueenKarma18/" title="View QueenKarma18's cam"><img alt="QueenKarma18" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/8/6/6/8667586.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/QueenKarma18/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="35 years old / Female / United States Of America">
# <p>35</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">Let's make a trip to my Temptation Island! Create Magic!</p>
# </div>
# <div class="cam-result first" id="sr-46664420">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/ClaraSweetTV/" title="View ClaraSweetTV's bio">ClaraSweetTV</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/ClaraSweetTV/" title="View ClaraSweetTV's cam"><img alt="ClaraSweetTV" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/4/7/9470440.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/ClaraSweetTV/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="26 years old / Female / France">
# <p>26</p>
# <p class="gender f">f</p>
# <p>FR</p>
# </div>
# <p class="headline">Soft and Glamour, The only one original Clara Sweet :)</p>
# </div>
# <div class="cam-result" id="sr-60066234">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/Eva_Monroe/" title="View Eva_Monroe's bio">Eva_Monroe</a></h2>
# <ul class="cam-features">
# <li class="phone" title="Confidential Phone Service">Confidential Phone Service</li>
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/Eva_Monroe/" title="View Eva_Monroe's cam"><img alt="Eva_Monroe" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/8/4/9842060.png" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/Eva_Monroe/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="33 years old / Female / United States Of America">
# <p>33</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">I &lt;3 CAM 2 CAM! Busty, wide hip cutie who loves to get naughty!</p>
# </div>
# <div class="cam-result" id="sr-14928094">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/SecretTeen/" title="View SecretTeen's bio">SecretTeen</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/SecretTeen/" title="View SecretTeen's cam"><img alt="SecretTeen" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/7/8/9782231.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/SecretTeen/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="18 years old / Female / Ukraine">
# <p>18</p>
# <p class="gender f">f</p>
# <p>UA</p>
# </div>
# <p class="headline">I have a SEXY LOOK and a TEEN BODY! I GIVE YOU all WHAT U WANNA!</p>
# </div>
# <div class="cam-result" id="sr-84577245">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/AlinaVibeMe/" title="View AlinaVibeMe's bio">AlinaVibeMe</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/AlinaVibeMe/" title="View AlinaVibeMe's cam"><img alt="AlinaVibeMe" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/6/9/9690737.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/AlinaVibeMe/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="18 years old / Female / Russian Federation">
# <p>18</p>
# <p class="gender f">f</p>
# <p>RU</p>
# </div>
# <p class="headline">I love bein your little angel!Lovense inside! Buz me 10$-15$-25$</p>
# </div>
# <div class="cam-result" id="sr-12848595">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/newdivacam/" title="View newdivacam's bio">newdivacam</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/newdivacam/" title="View newdivacam's cam"><img alt="newdivacam" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/7/3/9731351.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/newdivacam/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="27 years old / Female / Russian Federation">
# <p>27</p>
# <p class="gender f">f</p>
# <p>RU</p>
# </div>
# <p class="headline">I would advise You to sit back, relax and enjoy my company</p>
# </div>
# <div class="cam-result first" id="sr-77981225">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/Sugar_steep_doll/" title="View Sugar_steep_doll's bio">Sugar_steep_d…</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/Sugar_steep_doll/" title="View Sugar_steep_doll's cam"><img alt="Sugar_steep_doll" class="thumb" height="105" src="//m2.nsimg.net/thumb/snap/77981225.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/Sugar_steep_doll/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="20 years old / Female / United States Of America">
# <p>20</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">Sexy chubby american girl home alone. Lets explore eachother!</p>
# </div>
# <div class="cam-result" id="sr-74361052">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/LillyJames4u/" title="View LillyJames4u's bio">LillyJames…</a></h2>
# <ul class="cam-features">
# <li class="phone" title="Confidential Phone Service">Confidential Phone Service</li>
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/LillyJames4u/" title="View LillyJames4u's cam"><img alt="LillyJames4u" class="thumb" height="105" src="//m1.nsimg.net/thumb/snap/74361052.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/LillyJames4u/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="35 years old / Female / United States Of America">
# <p>35</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">Sexy hot dirty talking role playing c2c fun right here lets play</p>
# </div>
# <div class="cam-result" id="sr-45885709">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/PoissonIvyy/" title="View PoissonIvyy's bio">PoissonIvyy</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/PoissonIvyy/" title="View PoissonIvyy's cam"><img alt="PoissonIvyy" class="thumb" height="105" src="//m2.nsimg.net/thumb/snap/45885709.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/PoissonIvyy/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="24 years old / Female / Colombia">
# <p>24</p>
# <p class="gender f">f</p>
# <p>CO</p>
# </div>
# <p class="headline">I am shy but not holy, I will do dirty things, in a way elegant</p>
# </div>
# <div class="cam-result" id="sr-74701043">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/DominaDelilahShears/" title="View DominaDelilahShears's bio">DominaDelilah…</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/DominaDelilahShears/" title="View DominaDelilahShears's cam"><img alt="DominaDelilahShears" class="thumb" height="105" src="//m2.nsimg.net/thumb/snap/74701043.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/DominaDelilahShears/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating4"></div>
# </div>
# <div class="age" title="33 years old / Female / United States Of America">
# <p>33</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">I am your escape! Roleplay, Femdom, JOI, CEI and much more!</p>
# </div>
# <div class="cam-result" id="sr-51914087">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/Fit_Gal/" title="View Fit_Gal's bio">Fit_Gal</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/Fit_Gal/" title="View Fit_Gal's cam"><img alt="Fit_Gal" class="thumb" height="105" src="//m2.nsimg.net/thumb/snap/51914087.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/Fit_Gal/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="37 years old / Female / Spain">
# <p>37</p>
# <p class="gender f">f</p>
# <p>ES</p>
# </div>
# <p class="headline">Fun, bubbly, sexy and sensual. Come and chat and play...</p>
# </div>
# <div class="cam-result first" id="sr-45052663">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/ELYSSAx/" title="View ELYSSAx's bio">ELYSSAx</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/ELYSSAx/" title="View ELYSSAx's cam"><img alt="ELYSSAx" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/6/3/9636428.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/ELYSSAx/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="18 years old / Female / Romania">
# <p>18</p>
# <p class="gender f">f</p>
# <p>RO</p>
# </div>
# <p class="headline">Do u wonder what a mystery is? Well, check under my sheets;)</p>
# </div>
# <div class="cam-result" id="sr-22123512">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/Sexy_Erotic_Sarah/" title="View Sexy_Erotic_Sarah's bio">Sexy_Eroti…</a></h2>
# <ul class="cam-features">
# <li class="phone" title="Confidential Phone Service">Confidential Phone Service</li>
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/Sexy_Erotic_Sarah/" title="View Sexy_Erotic_Sarah's cam"><img alt="Sexy_Erotic_Sarah" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/5/7/7/5779819.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/Sexy_Erotic_Sarah/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="23 years old / Female / United States Of America">
# <p>23</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">Call me Sarah Sparkle, I make your cock feel good (;</p>
# </div>
# <div class="cam-result" id="sr-48438111">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/EmiliaClarkson/" title="View EmiliaClarkson's bio">EmiliaClarkson</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/EmiliaClarkson/" title="View EmiliaClarkson's cam"><img alt="EmiliaClarkson" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/5/5/9556087.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/EmiliaClarkson/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="22 years old / Female / Spain">
# <p>22</p>
# <p class="gender f">f</p>
# <p>ES</p>
# </div>
# <p class="headline">The Perfect combination: muscular strength and beauty...</p>
# </div>
# <div class="cam-result" id="sr-47616362">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/HollyHanley/" title="View HollyHanley's bio">HollyHanley</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/HollyHanley/" title="View HollyHanley's cam"><img alt="HollyHanley" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/7/2/9722345.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/HollyHanley/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="29 years old / Female / United States Of America">
# <p>29</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">Professional BBW Slut Puppy at your service - Let's get dirty!</p>
# </div>
# <div class="cam-result" id="sr-44750706">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/Allice_Rodriguez/" title="View Allice_Rodriguez's bio">Allice_Rodrig…</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/Allice_Rodriguez/" title="View Allice_Rodriguez's cam"><img alt="Allice_Rodriguez" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/3/8/9382336.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/Allice_Rodriguez/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating4_half"></div>
# </div>
# <div class="age" title="25 years old / Female / Colombia">
# <p>25</p>
# <p class="gender f">f</p>
# <p>CO</p>
# </div>
# <p class="headline">Let our imagination be the invisible character but always active</p>
# </div>
# <div class="cam-result first" id="sr-91709666">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/MillieRoseBabestation/" title="View MillieRoseBabestation's bio">MillieRoseBab…</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/MillieRoseBabestation/" title="View MillieRoseBabestation's cam"><img alt="MillieRoseBabestation" class="thumb" height="105" src="//m2.nsimg.net/thumb/178x134/9/8/8/9888469.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/MillieRoseBabestation/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating4"></div>
# </div>
# <div class="age" title="21 years old / Female / United Kingdom (Great Britain)">
# <p>21</p>
# <p class="gender f">f</p>
# <p>GB</p>
# </div>
# </div>
# <div class="cam-result" id="sr-48350955">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/PrimetimeIsla/" title="View PrimetimeIsla's bio">PrimetimeIsla</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/PrimetimeIsla/" title="View PrimetimeIsla's cam"><img alt="PrimetimeIsla" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/8/0/9/8095024.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/PrimetimeIsla/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="27 years old / Female / United States Of America">
# <p>27</p>
# <p class="gender f">f</p>
# <p>US</p>
# </div>
# <p class="headline">worldclass hustle. bonafide. tiniest violin playing &lt;3</p>
# </div>
# <div class="cam-result" id="sr-36622933">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/SammyLee/" title="View SammyLee's bio">SammyLee</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# <div class="thumb-wrapper">
# <a class="primaryBioLink" href="https://streamate.com/cam/SammyLee/" title="View SammyLee's cam"><img alt="SammyLee" class="thumb" height="105" src="//m1.nsimg.net/thumb/178x134/9/8/3/9830744.jpg" width="140"/></a>
# <p class="status partychat"><a href="https://streamate.com/cam/SammyLee/">Party Chat</a></p>
# </div>
# <div class="rating">
# <div class="rating-stars rating5"></div>
# </div>
# <div class="age" title="19 years old / Female / Spain">
# <p>19</p>
# <p class="gender f">f</p>
# <p>ES</p>
# </div>
# <p class="headline">I am a very tender, sweet girl but it does not mean that I can n</p>
# </div>
# <div class="cam-result" id="sr-67122777">
# <h2><a class="secondaryBioLink" href="https://streamate.com/cam/BonieJade/" title="View BonieJade's bio">BonieJade</a></h2>
# <ul class="cam-features">
# <li class="hd-video" title="High Definition Video">High Definition Video</li>
# <li class="audio" title="Audio">Audio</li>
# </ul>
# ...
# <dd class="">
# <a class="block" href="/webcam/trans/" title="Live Trangender Cams - Free Trans Live on Webcam at Streamate">Transgirl</a> <a href="/webcam/trans/" title="Live Trangender Cams - Free Trans Live on Webcam at Streamate"><font class="live">145 Live</font></a>
# </dd>
# <dd class="">
# <a class="block" href="/webcam/trimmed/" title="Trimmed Pussy Live Sex, Live Webcam Girls with Trimmed Pussy, Trimmed Pussy Webcams, Shaved Vagina">Trimmed Pussy</a> <a href="/webcam/trimmed/" title="Trimmed Pussy Live Sex, Live Webcam Girls with Trimmed Pussy, Trimmed Pussy Webcams, Shaved Vagina"><font class="live">652 Live</font></a>
# </dd>
# <dd class="">
# <a class="block" href="/webcam
# </ul>
# </div>
# </div>
# <!-- #wrapper-container -->
# <div class="container-bg-width" id="footer-container">
# <div class="footer">
# <div class="footer-content clearfix">
# <div class="footer-column">
# <div class="footer-section">
# <h3>Navigate</h3>
# <ul>
# <li><a href="https://www.streamate.com/?" title="Streamate Live Cams, Free Sex Cams, Sex 24/7">Homepage</a><a href="https://www.streamate.com/?"></a></li>
# <li><a href="https://www.streamate.com/advanced-search.html?" id="ta-footer-adv-search">Advanced Search</a></li>
# <li><a href="https://www.streamate.com/new.php?">New Models</a></li>
# <li><a href="https://www.streamate.com/about-us.html?" title="About Streamate">About Us</a></li>
# <li><a href="https://www.streamate.com/login.php">Member Login</a></li>
# <!-- Optional report spam link, set in skin congif [CUBBY_GLOBAL_SITE] reportspam_url -->
# <li></li>
# </ul>
# </div>
# <div class="footer-section">
# <h3>Become a Model</h3>
# <p>If you want to work from home, be your own boss, set your own schedule and chat live on your private webcam... <a href="http://www.streamatemodels.com" title="Make Money From Home - Become a Streamate Model">click here</a> to become a model today.</p>
# </div>
# <!-- Optional skin affiliate advert section -->
# <div class="footer-section">
# <h3>Webmasters Make Money with Streamate</h3>
# <p>Streamate is partnering with webmasters, bloggers or just about anybody who wants to make some extra money by telling people about our site. Head on over to <a href="https://cambuilder.com/" target="_blank">https://cambuilder.com/</a> to get started.</p>
# </div>
# </div>
# <div class="footer-column right-column">
# <div class="footer-section">
# <h3>Need assistance?</h3>
# <p><span class="copyright">Our customer service representatives are available 24 hours a day, 7 days a week, 365 days a year to assist you with any issues you might have. We offer live chat support, email and phone support, whichever you prefer.</span></p>
# <ul>
# <li><a href="https://www.streamate.com/customer-service/?">Customer service</a></li>
# <li><a href="https://www.streamate.com/customer-service/faq.html?">Frequently asked questions</a><a href="#"></a></li>
# </ul>
# </div>
# <div class="footer-section">
# <h3>Legal</h3>
# <ul>
# <li><a href="https://www.streamate.com/2257.html?">18 U.S.C. 2257 and 2257A Record-Keeping Requirements Compliance Statement</a></li>
# <li><a href="https://www.streamate.com/docs.php?doc=dmca&amp;">DMCA Notice of Copyright Infringement</a></li>
# <li><a href="https://www.streamate.com/terms.html?">Terms &amp; Conditions</a></li>
# <li><a href="https://www.streamate.com/privacy.html?">Privacy Policy</a></li>
# </ul>
# <div class="credentials">
# <p>All models appearing on this website are 18 years or older.</p>
# <img alt="" border="0" height="31" src="https://m1.nsimg.net/shared/rta.gif" width="88"/> <img alt="" border="0" height="31" src="https://m1.nsimg.net/shared/asacp.gif" width="88"/>
# </div>
# <p class="copyright"><b>© 2003 – 2020 streamate.com. All rights reserved.</b></p>
# </div>
# </div>
# </div>
# <img alt="" border="0" height="1" id="naiad_jp" width="1"/>
# <noscript>
# <img alt="pixeltracker" class="hide" src="//a.air2s.com/v1/info/pixel?smrid=32496983495732799692138847359784423198-1599007388-1537355771&amp;smtid=03f32206-30ce-4bc7-bb66-3afe46f68898G0111599007388&amp;smeid=5c5cf583-4207-4a23-8c3e-c1bc669fcc9bG0111599007388&amp;href=https%3A%2F%2Fstreamate.com%2F&amp;referrer=">
# </img></noscript>
# <script crossorigin="anonymous" integrity="sha384-tNOYgw5i4AePWqIeSedWaD2HVjJ+e5aMr63Y1uG8mv2FW5yuFtAW7NOQd5sKbhBi" src="//ga.nsimg.net/icf-analytics.js?smrid=32496983495732799692138847359784423198-1599007388-1537355771" type="text/javascript"></script>
# <script type="application/ld+json">
# 	  {
# 		  "@context": "http://schema.org",
# 		  "@type": "WebSite",
# 		  "url": "https://www.streamate.com",
# 		  "name": "Streamate",
# 		  "potentialAction": {
# 		    "@type": "SearchAction",
# 		    "target": "https://www.streamate.com/search.php?q={search_term_string}",
# 		    "query-input": "required name=search_term_string"
# 		  }
# 	  }
# 	</script>
# </div>
# <div id="bottom-text">
# <p>Streamate LIVE SEX CAM is the best quality live webcam available. Chat for free live 1-on-1 with these hotties, watch a show you'll never forget or join in on the action and let them see and hear you with our cam2cam feature! Streamate is the most popular live cam community featuring sexy amateurs and pornstars from all over the world.</p>
# </div>
# </div>
# <noscript>
# <img alt="nojstracking" class="hide" src="https://streamate.com/pixel/nojs.php"/>
# </noscript>
# <script src="//m2.nsimg.net/cache/js/bundle/naiad/20151203/naiad.js" type="text/javascript"></script>
# <script type="text/javascript">
# window.suggestmeyes_loaded = true;
# Naiad.Init({mediabase:'https://m1.nsimg.net',state:'',wwwbase:location.protocol+'//'+location.hostname});
#
# Naiad.OnDomReadyQueue([ 50, function() {
#   Naiad.AddTimezoneHiddenField( 'form[action$="/login.php"], input[name="trylogin"]' );
#   Naiad.BasicUser.DisplaySalutation( 'Welcome back <span>[#nickname]</span>' );
#   Naiad.Util.SearchAnythingChecker( 'Search Anything', '.search-form', '#search-anything');
#   Naiad.Util.InitLanguageSelect( '#choose-language A', '#choose-language SPAN' );
#   Naiad.Util.InitLegalAddresses( '.js-legal-address-fallback' );
#   var naiad_jp = Naiad.Y.one('#naiad_jp');
#   if( naiad_jp )
#   {
#     naiad_jp.set("src", Naiad.GetFooterPixel());
#   }
# }, '' ], [ 60, function() {
#   Naiad.Util.InitClearNotice( '.public-note' );
# }, '' ]);
#
# Naiad.OnLoadQueue([ 0, function() {
#   setTimeout(function () {
#     var is404 = !!Naiad.Y.one('#error-page');
#     Naiad.LogPerformanceTiming(is404);
#   }, 0);
# }, '' ]);
# </script>
# <script crossorigin="anonymous" integrity="sha384-oYZtQnzrOwpfpv6NuZeCRnhFJb2FfPXmnK3P/S/GUXRpj3OQnuGLRZuFnR13ZMAQ" src="//m2.nsimg.net/cache/js/smfid.min.js" type="text/javascript"></script>
# <script type="text/javascript">
# var base_media_uri = '//m1.nsimg.net/';
# Naiad.OnDomReadyQueue(
# 	[ 10, function() {
# 		  Naiad.Util.ImageGroup( 'DIV.cam-result', /^sr\-/, 'img-', { width: 140, height: 105 }, { foldDistance: 30 } )
# 		}, '' ],
#   [ 5, function()
#     {
#       if(typeof Naiad.SessionHistory != 'undefined')
#       {
#         Naiad.SessionHistory.showChatHistory();
#       }
#     }, '' ]
# );
#
#
# </script>
# <script type="text/javascript">
#   Naiad.OnDomReadyQueue([50, function () {
#     var showBanner = true;
#     try {
#       localStorage.setItem('smLocalStorage', (new Date()).getTime());
#       localStorage.removeItem('smLocalStorage');
#     }
#     catch (e) {
#       showBanner = false;
#     }
#
#     var Y = Naiad.Y,
#       seenPayPalNotice = false;
#
#     Y.use('cookie', 'node-base', function(Y) {
#       seenPayPalNotice = Y.Cookie.get('seenPayPalNotice') === 'seen';
#
#       if (showBanner && !seenPayPalNotice) {
#         Y.Node.create(' \
#           <div id="js-paypal-notice" class="cookie-notice"> \
#             <h4><span>18+</span> This site contains sexually explicit material</h4> \
#             <p>Enter ONLY if you are Over 18. By using the site. I accept the <a href=\"https://streamate.com/privacy.html\" target=\"_blank\" data-ajax=\"false\">Cookie</a> policies, <a href=\"https://streamate.com/terms.html\" target=\"_blank\" data-ajax=\"false\">Terms and Conditions</a> and <a href=\"https://streamate.com/privacy.html\" target=\"_blank\" data-ajax=\"false\">Privacy Policy</a>. <a href=\"http://google.com\" data-ajax=\"false\" class=\"leave\">No, I will leave.</a></p> \
#             <p><a href="#" data-ajax="false" class="agree btn"><span><span>I Agree</span></span></a></p> \
#           </div> \
#         ').appendTo('body');
#
#         Y.one('#js-paypal-notice .agree').on('click', function (e) {
#           Y.one(e.currentTarget).get('parentNode').remove();
#           Y.Cookie.set('seenPayPalNotice', 'seen', {
#             expires: new Date("January 01, 9999"),
#             path: '/'
#           });
#         });
#       }
#     });
#   }, '']);
# </script>

# %%
def get_text():
    global soup, text
    for script in soup(["script", "style"]):                   
        script.decompose()
    text = soup.get_text().replace("\n"," ")
    text = re.sub('\s+',' ',text)
    return text

# %%
get_text()
# Out:
# " Streamate - Live Sex Web Cam Video Chat - Free Memberships, XXX Live Sex Girls Streamate Live Cams, Free Sex Cams, Sex 24/7 Join Free Email Password Remember Me Forgot your password? Choose your language » Deutsch | Español | Français | Italiano | Nederlands | Norsk | Português | Svenska Home Search New Models Support Member Login Show Calendar Soon we will no longer be supporting your device or browser. Please update to enjoy your chat experience. Live Sex Chat - Amateur Cams and Pornstars Sort by: LanguagesEnglishFrenchSpanishItalianGermanSwedishPortugueseDutchNorwegian RegionsNorth America/UK/AustraliaWestern EuropeCentral/Eastern EuropeCentral/South AmericaAsiaAfrica FeaturesHD (best quality)AudioPhoneParty ChatGold Show Submit itsdanilynn High Definition Video Audio Party Chat 28 f US Amandababyxx High Definition Video Audio Party Chat 22 f US KamiliaMae High Definition Video Audio Live Now 31 f US Blonde slut with a tight pussy and fat ass here to please. AmberSparkx High Definition Video Audio Party Chat 26 f CA Fetishista Friendly! Sexy, Smoking, Kinky, Femdom.. LexisLove High Definition Video Audio Party Chat 50 f US Hey lovers this is lexis i love to squirt all over SummerJaym… Confidential Phone Service High Definition Video Audio Party Chat 27 f US Let me be your dream girl in every, and any, way possible... ZoeyAndrews High Definition Video Audio Party Chat 47 f US It is almost clean slate time but I am keeping my slate dirty! IbizaLuci Confidential Phone Service High Definition Video Audio Party Chat 25 f US Fetish Friendly Brazilian Beauty with the best tits and ass! ExoticArya High Definition Video Audio Party Chat 29 f US Sexy Fit Athletic Asian girl To fulfill your desires and fantasy Delilah112 Confidential Phone Service High Definition Video Audio Party Chat 50 f US This is my very first time camming ever! Cum take my cam cherry! SophiaBailey High Definition Video Audio Party Chat 24 f US My mouth does a lot of talking, among other things ... LyzMania Confidential Phone Service High Definition Video Audio Gold Show 19 f CY Wondering what are you looking for, because i'm not usual. Kiss Amy_Amerson High Definition Video Audio Party Chat 23 f CA Canadian sweetheart. The girl next door with a very naughty side Jayne_Cobb High Definition Video Audio Party Chat 33 f US Milfy fucker with flying dildos and dad jokes. Who wants to fuck niacruz High Definition Video Audio Party Chat 19 f CO Love Spank My Ass While You Make Me, Take Clothes Off... XxDevilsBride… High Definition Video Audio Party Chat 22 f RU I'm a romantic and funny girl. I'm not bored with me))))) HotSasHa High Definition Video Audio Gold Show 24 f GB Rate me 5 star and I'll send you 10 Videos as a Gift Hanna_Evans Confidential Phone Service High Definition Video Audio Party Chat 24 f CO Good sense of humor, dirty mind and beautiful heart. MissyJolie Confidential Phone Service High Definition Video Audio Party Chat 42 f RO I am new here guys, come in and lets have some fun together ;) QueenKarma… Confidential Phone Service High Definition Video Audio Party Chat 35 f US Let's make a trip to my Temptation Island! Create Magic! ClaraSweetTV High Definition Video Audio Party Chat 26 f FR Soft and Glamour, The only one original Clara Sweet :) Eva_Monroe Confidential Phone Service High Definition Video Audio Party Chat 33 f US I <3 CAM 2 CAM! Busty, wide hip cutie who loves to get naughty! SecretTeen High Definition Video Audio Party Chat 18 f UA I have a SEXY LOOK and a TEEN BODY! I GIVE YOU all WHAT U WANNA! AlinaVibeMe High Definition Video Audio Party Chat 18 f RU I love bein your little angel!Lovense inside! Buz me 10$-15$-25$ newdivacam High Definition Video Audio Party Chat 27 f RU I would advise You to sit back, relax and enjoy my company Sugar_steep_d… High Definition Video Audio Party Chat 20 f US Sexy chubby american girl home alone. Lets explore eachother! LillyJames… Confidential Phone Service High Definition Video Audio Party Chat 35 f US  ...

# %%
#Tabla con los lenguajes
langs = pd.read_excel("langs.xlsx")
langs
# Out:
#            Language ISO Code
# 0         Abkhazian       ab
# 1              Afar       aa
# 2         Afrikaans       af
# 3              Akan       ak
# 4          Albanian       sq
# ..              ...      ...
# 186           Xhosa       xh
# 187         Yiddish   yi, ji
# 188          Yoruba       yo
# 189  Zhuang, Chuang       za
# 190            Zulu       zu
#
# [191 rows x 2 columns]

# %%
def get_language():
    global soup, langs
    lang = langdetect.detect(text)
    lang = langs[langs["ISO Code"] == lang]["Language"]
    return lang

# %%
get_language()
# Out:
# 42    English
# Name: Language, dtype: object

# %%
# nlp = spacy.load("es_core_news_sm")
nlp = spacy.load("en_core_web_sm")
def get_names():
    doc = nlp(text)
    person = []
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            person.append(ent)
    return person

# %%
get_names()
# Out:
# [Free Sex Cams,
#  Login Show Calendar,
#  Live Sex Chat - Amateur Cams,
#  Cum,
#  Videos,
#  MissyJolie Confidential,
#  Glamour,
#  Clara Sweet,
#  Busty,
#  Sarah Sparkle,
#  MAKE U HAPPY=,
#  Lets,
#  blondntrashy Confidential,
#  Aussie]
